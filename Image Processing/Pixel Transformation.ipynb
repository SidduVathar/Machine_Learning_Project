# %% [markdown]
# ***Pixel Transformation***
#
# Histograms and Intensity Transformations

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
# Define a function to plot the two images sidu-by-side
def plot_image(image_1, image_2,title_1="Orignal", title_2="New Image"):
    plt.figure(figsize=(5,5))
    plt.subplot(1, 2, 1)
    plt.imshow(image_1,cmap="gray")
    plt.title(title_1)
    plt.subplot(1, 2, 2)
    plt.imshow(image_2,cmap="gray")
    plt.title(title_2)
    plt.show()

# %%
# Lets define another helper function. The following one will plot two histograms side-by-side.
def plot_hist(old_image, new_image,title_old="Orignal", title_new="New Image"):
    intensity_values=np.array([x for x in range(256)])
    plt.subplot(1, 2, 1)
    plt.bar(intensity_values, cv2.calcHist([old_image],[0],None,[256],[0,256])[:,0],width = 5)
    plt.title(title_old)
    plt.xlabel('intensity')
    plt.subplot(1, 2, 2)
    plt.bar(intensity_values, cv2.calcHist([new_image],[0],None,[256],[0,256])[:,0],width = 5)
    plt.title(title_new)
    plt.xlabel('intensity')
    plt.show()

# %% [markdown]
# Histograms

# %%
# Let's conside a image with taking below values
img=np.array([[0,2,2],[1,1,1],[1,1,2]],dtype=np.uint8)
plt.imshow(img, cmap="gray")
plt.show()
print("img",img)
# Out:
# img [[0 2 2]
#  [1 1 1]
#  [1 1 2]]

# %%
# plt.bar([x for x in range(6)],[1,8,0,1,0,0])
# plt.show()

# %%
# plt.bar([x for x in range(6)],[0,2,2,0,0,6])
# plt.show()

# %% [markdown]
# Gray Scale Histograms

# %%
hill=cv2.imread("D:\Student\Projects\Computer Vision and Image processing\images\im3.jpg")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\Win11\AppData\Local\Temp\ipykernel_12780\365575117.py:1: SyntaxWarning: invalid escape sequence '\S'
#   hill=cv2.imread("D:\Student\Projects\Computer Vision and Image processing\images\im3.jpg")

# %%
# BGR_to_RGB
cv_hill=cv2.cvtColor(hill,cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(4,4))
plt.imshow(cv_hill)
plt.show()

# %% [markdown]
# Intensity Transformations

# %%
# We can perform intensity transformation using a function f(x,y) x-rows of pixels and Y-columns of pixels
nature=cv2.imread("D:\Student\Projects\Computer Vision and Image processing\images\im6.jpg")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\S'
# <>:2: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\Win11\AppData\Local\Temp\ipykernel_12780\538159711.py:2: SyntaxWarning: invalid escape sequence '\S'
#   nature=cv2.imread("D:\Student\Projects\Computer Vision and Image processing\images\im6.jpg")

# %%
# BGR_to_RGB
cv_nature=cv2.cvtColor(hill,cv2.COLOR_BGR2RGB)

# %%
cv_nature = 255 - cv_nature

print("cv_nature\n", cv_nature)
print("cv_nature\n", cv_nature)
# Out:
# cv_nature
#  [[[ 48  60  58]
#   [ 37  49  47]
#   [ 47  59  57]
#   ...
#   [113 115 102]
#   [111 113 100]
#   [104 106  93]]
#
#  [[ 42  54  52]
#   [ 39  51  49]
#   [ 51  63  61]
#   ...
#   [111 113 100]
#   [106 108  95]
#   [102 104  91]]
#
#  [[ 40  52  48]
#   [ 40  52  48]
#   [ 50  62  58]
#   ...
#   [110 110 100]
#   [103 103  93]
#   [104 104  94]]
#
#  ...
#
#  [[228 212 197]
#   [225 212 196]
#   [216 200 185]
#   ...
#   [100 114   1]
#   [120 134  21]
#   [130 144  30]]
#
#  [[255 245 229]
#   [255 251 235]
#   [255 246 230]
#   ...
#   [ 50  63   0]
#   [ 59  72   0]
#   [118 131  39]]
#
#  [[240 228 212]
#   [255 244 228]
#   [255 248 232]
#   ...
#   [ 30  41   0]
#   [ 34  46   0]
#   [ 85  97  15]]]
# cv_nature
#  [[[ 48  60  58]
#   [ 37  49  47]
#   [ 47  59  57]
#   ...
#   [113 115 102]
#   [111 113 100]
#   [104 106  93]]
#
#  [[ 42  54  52]
#   [ 39  51  49]
#   [ 51  63  61]
#   ...
#   [111 113 100]
#   [106 108  95]
#   [102 104  91]]
#
# ...

# %%
plt.figure(figsize=(10,10))
plt.subplot(1, 2, 1) 
plt.imshow(cv_nature,cmap="gray")
plt.subplot(1, 2, 2)
plt.imshow(cv_nature,cmap="gray")
plt.show()
print("nature:",cv_nature)
# Out:
# nature: [[[ 48  60  58]
#   [ 37  49  47]
#   [ 47  59  57]
#   ...
#   [113 115 102]
#   [111 113 100]
#   [104 106  93]]
#
#  [[ 42  54  52]
#   [ 39  51  49]
#   [ 51  63  61]
#   ...
#   [111 113 100]
#   [106 108  95]
#   [102 104  91]]
#
#  [[ 40  52  48]
#   [ 40  52  48]
#   [ 50  62  58]
#   ...
#   [110 110 100]
#   [103 103  93]
#   [104 104  94]]
#
#  ...
#
#  [[228 212 197]
#   [225 212 196]
#   [216 200 185]
#   ...
#   [100 114   1]
#   [120 134  21]
#   [130 144  30]]
#
#  [[255 245 229]
#   [255 251 235]
#   [255 246 230]
#   ...
#   [ 50  63   0]
#   [ 59  72   0]
#   [118 131  39]]
#
#  [[240 228 212]
#   [255 244 228]
#   [255 248 232]
#   ...
#   [ 30  41   0]
#   [ 34  46   0]
#   [ 85  97  15]]]

# %%
image = cv2.imread("D:\Student\Projects\Computer Vision and Image processing\images\mammogram.png", cv2.IMREAD_GRAYSCALE)
cv2.rectangle(image, pt1=(160, 212), pt2=(250, 289), color = (255), thickness=2) 

plt.figure(figsize = (10,10))
plt.imshow(image, cmap="gray")
plt.show()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\Win11\AppData\Local\Temp\ipykernel_12780\2720040465.py:1: SyntaxWarning: invalid escape sequence '\S'
#   image = cv2.imread("D:\Student\Projects\Computer Vision and Image processing\images\mammogram.png", cv2.IMREAD_GRAYSCALE)

# %%
# Apply the intensity transformation:
img_neg = 255 - image

# %%
# We see that the micro-calcifications in the negative image are easier to analyze.
plt.figure(figsize=(10,10))
plt.imshow(img_neg, cmap = "gray")
plt.show()

# %% [markdown]
# ***Brightness and contrast adjustments***
#
# We can use multiplication by alpha for contrast control and addition by beta to improve brightness control.

# %%
# We can perform intensity transformation using a function f(x,y) x-rows of pixels and Y-columns of pixels
goldhill=cv2.imread("D:\Student\Projects\Computer Vision and Image processing\images\goldhill.bmp")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\S'
# <>:2: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\Win11\AppData\Local\Temp\ipykernel_12780\361438768.py:2: SyntaxWarning: invalid escape sequence '\S'
#   goldhill=cv2.imread("D:\Student\Projects\Computer Vision and Image processing\images\goldhill.bmp")

# %%
alpha = 1 # Simple contrast control
beta = 100   # Simple brightness control   
new_image = cv2.convertScaleAbs(goldhill, alpha=alpha, beta=beta)

# %%
# Plot the brighter image
plot_image(goldhill, new_image, title_1 = "Orignal", title_2 = "brightness control")

# %%
# Brighter image histogram is shifted
plt.figure(figsize=(10,5))
plot_hist(goldhill, new_image, "Orignal", "brightness control")

# %%
# Increase the constrast by increasing alpha
plt.figure(figsize=(10,5))
alpha = 2# Simple contrast control
beta = 0 # Simple brightness control   # Simple brightness control
new_image = cv2.convertScaleAbs(goldhill, alpha=alpha, beta=beta)

plot_image(goldhill,new_image,"Orignal","contrast control")

# %%
plt.figure(figsize=(10,5))
plot_hist(goldhill, new_image,"Orignal","contrast control")

# %%
# Other way around
plt.figure(figsize=(10,5))
alpha = 3 # Simple contrast control
beta = -200  # Simple brightness control   
new_image = cv2.convertScaleAbs(goldhill, alpha=alpha, beta=beta)

# %%
plot_image(goldhill, new_image, "Orignal", "brightness & contrast control")

# %%
plt.figure(figsize=(10,5))
plot_hist(goldhill, new_image, "Orignal", "brightness & contrast control")

# %% [markdown]
# Histogram Equalization

# %%
# Histogram Equalization increases the contrast of images, by stretching out the range of the grayscale pixels; It does this by flatting the histogram
# Load zelda image (fix backslashes and path)
zelda = cv2.imread(r"D:\Student\Projects\Computer Vision and Image processing\images\zelda.png", cv2.IMREAD_GRAYSCALE)
new_image = cv2.equalizeHist(zelda)

# %%
new_image = cv2.equalizeHist(zelda)

# %%
plot_image(zelda,new_image,"Orignal","Histogram Equalization")

# %%
plt.figure(figsize=(10,5))
plot_hist(zelda, new_image,"Orignal","Histogram Equalization")
