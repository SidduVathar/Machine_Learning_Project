# %% [markdown]
# Basic Image Topics Covered Using PIL and OpenCV

# %%
from PIL import Image, ImageOps
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
image= Image.open("D:/Student/Projects/Computer Vision and Image processing/images/baboon.png")

# %%
print(image.size,
image.mode)
# Out:
# (512, 512) RGB

# %%
gray_image=ImageOps.grayscale(image)

# %%
red, green , blue=image.split()

# %%
# Convert Image to a array
Array_Image= np.array(image)

print(Array_Image.size, Array_Image.shape)
# Out:
# 786432 (512, 512, 3)

# %%
Array_Image
# Out:
# array([[[164, 150,  71],
#         [ 63,  57,  31],
#         [ 75,  43,  10],
#         ...,
#         [117, 119,  68],
#         [141, 170, 101],
#         [179, 188, 118]],
#
#        [[120, 125,  62],
#         [135,  97,  33],
#         [ 55,  35,  23],
#         ...,
#         [122, 140,  98],
#         [136, 159, 128],
#         [120, 138,  74]],
#
#        [[ 99,  74,  31],
#         [132, 118,  46],
#         [ 60,  41,  36],
#         ...,
#         [118,  93,  90],
#         [ 87,  91,  77],
#         [ 96,  80,  49]],
#
#        ...,
#
#        [[121, 148, 155],
#         [123, 156, 150],
#         [124, 150, 139],
#         ...,
#         [110,  73,  60],
#         [ 90,  93,  70],
#         [ 81,  80,  60]],
#
#        [[126, 169, 168],
#         [117, 151, 151],
#         [121, 136, 133],
#         ...,
#         [ 73,  84,  68],
#         [ 99,  69,  86],
#         [ 80,  63,  71]],
#
#        [[  9,  11,  12],
#         [ 10,  12,  11],
#         [ 11,  15,  12],
# ...

# %%
Array_Image[0]
# Out:
# array([[164, 150,  71],
#        [ 63,  57,  31],
#        [ 75,  43,  10],
#        ...,
#        [117, 119,  68],
#        [141, 170, 101],
#        [179, 188, 118]], shape=(512, 3), dtype=uint8)

# %% [markdown]
# ***Read the Image Uisng OpenCV***

# %%
Image1=cv2.imread("D:/Student/Projects/Computer Vision and Image processing/images/cameraman.jpeg")

# %%
Image1
# Out:
# array([[[156, 156, 156],
#         [156, 156, 156],
#         [157, 157, 157],
#         ...,
#         [153, 153, 153],
#         [153, 153, 153],
#         [154, 154, 154]],
#
#        [[156, 156, 156],
#         [156, 156, 156],
#         [157, 157, 157],
#         ...,
#         [153, 153, 153],
#         [153, 153, 153],
#         [154, 154, 154]],
#
#        [[156, 156, 156],
#         [156, 156, 156],
#         [157, 157, 157],
#         ...,
#         [152, 152, 152],
#         [152, 152, 152],
#         [153, 153, 153]],
#
#        ...,
#
#        [[113, 113, 113],
#         [120, 120, 120],
#         [116, 116, 116],
#         ...,
#         [134, 134, 134],
#         [151, 151, 151],
#         [114, 114, 114]],
#
#        [[122, 122, 122],
#         [137, 137, 137],
#         [133, 133, 133],
#         ...,
#         [136, 136, 136],
#         [119, 119, 119],
#         [122, 122, 122]],
#
#        [[113, 113, 113],
#         [141, 141, 141],
#         [142, 142, 142],
# ...

# %%
plt.figure(figsize=(2,2))
plt.imshow(Image1)

# %%
plt.figure(figsize=(2,2))
plt.imshow(Image1[10:100])

# %%
Img=cv2.imread("D:/Student/Projects/Computer Vision and Image processing/images/im2.jpg")

# %%
plt.figure(figsize=(3,3))
new_image=cv2.cvtColor(Img,cv2.COLOR_BGR2RGB)
plt.imshow(new_image)

# %%
Img.max()
# Out:
# np.uint8(255)

# %%
Img.min()
# Out:
# np.uint8(0)
