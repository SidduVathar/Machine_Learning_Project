# %% [markdown]
# Linear Classifiers

# %% [markdown]
# :
# : Logistic Regression - It resembels the threshold function. Means if the value is greater x>=0.5 is equlal to 1 and x<=0.5 is equal to 0
# :
